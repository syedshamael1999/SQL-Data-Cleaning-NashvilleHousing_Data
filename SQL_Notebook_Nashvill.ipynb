-- %%
--1. Standardized Date Format
--The SaleDate format is DateTime. We just want date.
UPDATE NvHousing  
SET saleDate = CAST(saleDate AS DATE)
-- Out:
-- (56477 rows affected)
-- Total execution time: 00:00:00.161

-- %%
--Apparantly the previous Syntax dint show changes in the table. So we try another way.
--The SaleDate format is DateTime. We just want date.
--So we Create a new Create a new column with the Date format
ALTER TABLE NvHousing
ADD SalesDateCorrected  DATE
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.014

-- %%
UPDATE NvHousing
SET SalesDateCorrected = CAST(saleDate AS Date)
--FINDINGS: Seems like that woked. It created another Column witht he desired Date format.
-- Out:
-- (56477 rows affected)
-- Total execution time: 00:00:00.547

-- %%
--2. Populate Null Values
--Now we populate Null values in the PropertyAddress Column
--First we look at the adjacent columns
          --SELECT * 
          --FROM NvHousing
--FINDINGS: Seems like PropertAddress repeats itself many times.
          --Each ParcelID is linked to a particular address.
          --Example: 207 ROSEHILL  DR, GOODLETTSVILLE is repeated many times. And everytime it is repeated it has 025 08 0 006.00 ParcelID
--Solution Logic: We are going to join this table with itself and populate the "NULL" rows of PropertyAddress with the "NOT NULL" rows of PropertyAddress Based on ParcelID.
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00

-- %%
SELECT A.ParcelID, A.PropertyAddress, B.ParcelID, B.PropertyAddress
FROM NvHousing A
JOIN NvHousing B
     ON A.ParcelID = B.ParcelID
WHERE A.PropertyAddress IS NULL
AND B.PropertyAddress IS NOT NULL
-- Out:
-- (35 rows affected)
-- Total execution time: 00:00:00.070
-- <table><tr><th>ParcelID</th><th>PropertyAddress</th><th>ParcelID</th><th>PropertyAddress</th></tr><tr><td>107 13 0 107.00</td><td>NULL</td><td>107 13 0 107.00</td><td>1205  THOMPSON PL, NASHVILLE</td></tr><tr><td>025 07 0 031.00</td><td>NULL</td><td>025 07 0 031.00</td><td>410  ROSEHILL CT, GOODLETTSVILLE</td></tr><tr><td>026 01 0 069.00</td><td>NULL</td><td>026 01 0 069.00</td><td>141  TWO MILE PIKE, GOODLETTSVILLE</td></tr><tr><td>026 05 0 017.00</td><td>NULL</td><td>026 05 0 017.00</td><td>208  EAST AVE, GOODLETTSVILLE</td></tr><tr><td>026 06 0A 038.00</td><td>NULL</td><td>026 06 0A 038.00</td><td>109  CANTON CT, GOODLETTSVILLE</td></tr><tr><td>033 06 0 041.00</td><td>NULL</td><td>033 06 0 041.00</td><td>1129  CAMPBELL RD, GOODLETTSVILLE</td></tr><tr><td>033 06 0A 002.00</td><td>NULL</td><td>033 06 0A 002.00</td><td>1116  CAMPBELL RD, GOODLETTSVILLE</td></tr><tr><td>033 15 0 123.00</td><td>NULL</td><td>033 15 0 123.00</td><td>438  W CAMPBELL RD, GOODLETTSVILLE</td></tr><tr><td>108 07 0A 026.00</td><td>NULL</td><td>108 07 0A 026.00</td><td>908  PATIO DR, NASHVILLE</td></tr><tr><td>108 07 0A 026.00</td><td>NULL</td><td>108 07 0A 026.00</td><td>908  PATIO DR, NASHVILLE</td></tr><tr><td>034 03 0 059.00</td><td>NULL</td><td>034 03 0 059.00</td><td>2117  PAULA DR, MADISON</td></tr><tr><td>034 03 0 059.00</td><td>NULL</td><td>034 03 0 059.00</td><td>2117  PAULA DR, MADISON</td></tr><tr><td>034 07 0B 015.00</td><td>NULL</td><td>034 07 0B 015.00</td><td>2524  VAL MARIE DR, MADISON</td></tr><tr><td>034 07 0B 015.00</td><td>NULL</td><td>034 07 0B 015.00</td><td>2524 VAL MARIE  DR, MADISON</td></tr><tr><td>034 07 0B 015.00</td><td>NULL</td><td>034 07 0B 015.00</td><td>2524  VAL MARIE DR, MADISON</td></tr><tr><td>034 16 0A 004.00</td><td>NULL</td><td>034 16 0A 004.00</td><td>213 WARREN  CT, OLD HICKORY</td></tr><tr><td>041 03 0A 100.00</td><td>NULL</td><td>041 03 0A 100.00</td><td>1289  GOODMORNING DR, NASHVILLE</td></tr><tr><td>109 04 0A 080.00</td><td>NULL</td><td>109 04 0A 080.00</td><td>2537  JANALYN TRCE, HERMITAGE</td></tr><tr><td>110 03 0A 061.00</td><td>NULL</td><td>110 03 0A 061.00</td><td>2704  ALVIN SPERRY PASS, MOUNT JULIET</td></tr><tr><td>113 14 0A 002.00</td><td>NULL</td><td>113 14 0A 002.00</td><td>7601  CHIPMUNK LN, NASHVILLE</td></tr><tr><td>042 13 0 075.00</td><td>NULL</td><td>042 13 0 075.00</td><td>222  FOXBORO DR, MADISON</td></tr><tr><td>043 04 0 014.00</td><td>NULL</td><td>043 04 0 014.00</td><td>112  HILLER DR, OLD HICKORY</td></tr><tr><td>043 09 0 074.00</td><td>NULL</td><td>043 09 0 074.00</td><td>213 B  LOVELL ST, MADISON</td></tr><tr><td>043 13 0 308.00</td><td>NULL</td><td>043 13 0 308.00</td><td>224  HICKORY ST, MADISON</td></tr><tr><td>114 15 0A 030.00</td><td>NULL</td><td>114 15 0A 030.00</td><td>109  CEDAR PLACE BND, NASHVILLE</td></tr><tr><td>044 05 0 135.00</td><td>NULL</td><td>044 05 0 135.00</td><td>202  KEETON AVE, OLD HICKORY</td></tr><tr><td>052 01 0 296.00</td><td>NULL</td><td>052 01 0 296.00</td><td>726  IDLEWILD DR, MADISON</td></tr><tr><td>052 08 0A 320.00</td><td>NULL</td><td>052 08 0A 320.00</td><td>608  SANDY SPRING TRL, MADISON</td></tr><tr><td>092 06 0 273.00</td><td>NULL</td><td>092 06 0 273.00</td><td>2721  HERMAN ST, NASHVILLE</td></tr><tr><td>092 06 0 282.00</td><td>NULL</td><td>092 06 0 282.00</td><td>815  31ST AVE N, NASHVILLE</td></tr><tr><td>092 13 0 322.00</td><td>NULL</td><td>092 13 0 322.00</td><td>237  37TH AVE N, NASHVILLE</td></tr><tr><td>092 13 0 322.00</td><td>NULL</td><td>092 13 0 322.00</td><td>237  37TH AVE N, NASHVILLE</td></tr><tr><td>092 13 0 339.00</td><td>NULL</td><td>092 13 0 339.00</td><td>311  35TH AVE N, NASHVILLE</td></tr><tr><td>093 08 0 054.00</td><td>NULL</td><td>093 08 0 054.00</td><td>700  GLENVIEW DR, NASHVILLE</td></tr><tr><td>093 08 0 054.00</td><td>NULL</td><td>093 08 0 054.00</td><td>700  GLENVIEW DR, NASHVILLE</td></tr></table>

-- %%
UPDATE A
SET A.PropertyAddress = B.PropertyAddress
FROM NvHousing A
JOIN NvHousing B
     ON A.ParcelID = B.ParcelID
WHERE A.PropertyAddress IS NULL
AND B.PropertyAddress IS NOT NULL
--FINDINGS: Upon running SELECT * FROM NvHousing
-- Out:
-- (29 rows affected)
-- Total execution time: 00:00:00.080

-- %%
SELECT PropertyAddress
FROM NvHousing
WHERE PropertyAddress IS NULL
--FINDINGS: It Worked. There are no Null values in PropertyAddress now
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.112
-- <table><tr><th>PropertyAddress</th></tr></table>

-- %%
--3. Breaking out PropertyAddress into Individual Columns (Address, City) (Method 1)
--First we create new columns 
ALTER TABLE NvHousing
ADD PropertySplitAddress nvarchar(255),
    PropertySplitCity nvarchar(255)
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.009

-- %%
UPDATE NvHousing
SET PropertySplitAddress = LEFT(PropertyAddress, CHARINDEX(',', PropertyAddress) -1),
    PropertySplitCity = RIGHT(PropertyAddress, LEN(PropertyAddress) - CHARINDEX(',', PropertyAddress))
--That populated the new columns
-- Out:
-- (56477 rows affected)
-- Total execution time: 00:00:00.501

-- %%
--4. Breaking out OwnerAddress into Individual Columns (Address, City, State) (Method 2) 
ALTER TABLE NvHousing
ADD OwnerSplitAddress NVARCHAR(255),
    OwnerSplitCity NVARCHAR(255),
    OwnerSplitState NVARCHAR(255)
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.006

-- %%
UPDATE NvHousing
SET OwnerSplitAddress = PARSENAME(REPLACE(OwnerAddress, ',', '.'), 3),
    OwnerSplitCity = PARSENAME(REPLACE(OwnerAddress, ',', '.'), 2), 
    OwnerSplitState = PARSENAME(REPLACE(OwnerAddress, ',', '.'), 2) 
    --That populated the new columns
-- Out:
-- (56477 rows affected)
-- Total execution time: 00:00:00.574

-- %%
--5. Change Y and N to Yes and No in "SoldAsVacant" field
SELECT DISTINCT(SoldAsVacant)
FROM NvHousing
--Some of these rows have 'Y', 'N', 'Yes', 'No'
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.289
-- <table><tr><th>SoldAsVacant</th></tr><tr><td>N</td></tr><tr><td>Yes</td></tr><tr><td>Y</td></tr><tr><td>No</td></tr></table>

-- %%
UPDATE NvHousing
SET  SoldAsVacant = CASE 
                        WHEN SoldAsVacant = 'Y' THEN 'Yes'
                        WHEN SoldAsVacant = 'N' THEN 'No'
                        ELSE SoldAsVacant
                    END
FROM NvHousing
--FINDINGS: That replaced Y with Yes and N with No
-- Out:
-- (56477 rows affected)
-- Total execution time: 00:00:00.138

-- %%
--6. Remove Duplicates
--CTE - TO IDENTIFY DUPLICATE ROWS
WITH RowNumCTE AS (
SELECT *,
             ROW_NUMBER() OVER (
                                 PARTITION BY 
	                               ParcelID, 
				       PropertyAddress, 
				       SaleDate, 
				       SalePrice,
				       LegalReference
				       ORDER BY UniqueID) AS row_num  
     FROM NvHousing
)
SELECT *
FROM RowNumCTE
WHERE row_num >1
ORDER BY PropertyAddress
-- Out:
-- (104 rows affected)
-- Total execution time: 00:00:00.115
-- <table><tr><th>UniqueID </th><th>ParcelID</th><th>LandUse</th><th>PropertyAddress</th><th>SaleDate</th><th>SalePrice</th><th>LegalReference</th><th>SoldAsVacant</th><th>OwnerName</th><th>OwnerAddress</th><th>Acreage</th><th>TaxDistrict</th><th>LandValue</th><th>BuildingValue</th><th>TotalValue</th><th>YearBuilt</th><th>Bedrooms</th><th>FullBath</th><th>HalfBath</th><th>SalesDateCorrected</th><th>PropertySplitAddress</th><th>PropertySplitCity</th><th>OwnerSplitAddress</th><th>OwnerSplitCity</th><th>OwnerSplitState</th><th>row_num</th></tr><tr><td>27354</td><td>107 14 0 157.00</td><td>SINGLE FAMILY</td><td>1003  BRILEY PKWY, NASHVILLE</td><td>2015-02-12 00:00:00.000</td><td>80000</td><td>20150219-0014347</td><td>No</td><td>GREEN, KASSANDRA</td><td>1003  BRILEY PKWY, NASHVILLE, TN</td><td>0.22</td><td>URBAN SERVICES DISTRICT</td><td>17000</td><td>64600</td><td>81600</td><td>1949</td><td>2</td><td>2</td><td>0</td><td>2015-02-12</td><td>1003  BRILEY PKWY</td><td> NASHVILLE</td><td>1003  BRILEY PKWY</td><td> NASHVILLE</td><td> NASHVILLE</td><td>2</td></tr><tr><td>27383</td><td>150 04 0 144.00</td><td>SINGLE FAMILY</td><td>1005  ESTURBRIDGE CT, ANTIOCH</td><td>2015-02-13 00:00:00.000</td><td>180000</td><td>20150213-0013547</td><td>No</td><td>TINNEY, STU</td><td>1005  ESTURBRIDGE CT, ANTIOCH, TN</td><td>0.31</td><td>URBAN SERVICES DISTRICT</td><td>29500</td><td>131600</td><td>161100</td><td>1987</td><td>4</td><td>3</td><td>0</td><td>2015-02-13</td><td>1005  ESTURBRIDGE CT</td><td> ANTIOCH</td><td>1005  ESTURBRIDGE CT</td><td> ANTIOCH</td><td> ANTIOCH</td><td>2</td></tr><tr><td>27362</td><td>119 16 0 084.00</td><td>DUPLEX</td><td>1006  DRUMMOND DR, NASHVILLE</td><td>2015-02-17 00:00:00.000</td><td>80000</td><td>20150218-0014086</td><td>No</td><td>POST, KEVIN</td><td>1006  DRUMMOND DR, NASHVILLE, TN</td><td>0.99</td><td>URBAN SERVICES DISTRICT</td><td>14300</td><td>87500</td><td>101800</td><td>1958</td><td>4</td><td>3</td><td>0</td><td>2015-02-17</td><td>1006  DRUMMOND DR</td><td> NASHVILLE</td><td>1006  DRUMMOND DR</td><td> NASHVILLE</td><td> NASHVILLE</td><td>2</td></tr><tr><td>27132</td><td>091 08 0 056.00</td><td>SINGLE FAMILY</td><td>1011  43RD AVE N, NASHVILLE</td><td>2015-02-23 00:00:00.000</td><td>69900</td><td>20150227-0017102</td><td>No</td><td>MENDING HEARTS, INC.</td><td>1011  43RD AVE N, NASHVILLE, TN</td><td>0.17</td><td>URBAN SERVICES DISTRICT</td><td>20000</td><td>41600</td><td>61600</td><td>1940</td><td>3</td><td>2</td><td>0</td><td>2015-02-23</td><td>1011  43RD AVE N</td><td> NASHVILLE</td><td>1011  43RD AVE N</td><td> NASHVILLE</td><td> NASHVILLE</td><td>2</td></tr><tr><td>27368</td><td>135 10 0E 020.00</td><td>RESIDENTIAL CONDO</td><td>1023  CAPITAL FUNDS CT, NASHVILLE</td><td>2015-02-06 00:00:00.000</td><td>118981</td><td>20150210-0012380</td><td>No</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>2015-02-06</td><td>1023  CAPITAL FUNDS CT</td><td> NASHVILLE</td><td>NULL</td><td>NULL</td><td>NULL</td><td>2</td></tr><tr><td>27369</td><td>135 10 0E 021.00</td><td>RESIDENTIAL CONDO</td><td>1025  CAPITAL FUNDS CT, NASHVILLE</td><td>2015-02-06 00:00:00.000</td><td>118981</td><td>20150210-0012389</td><td>No</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>2015-02-06</td><td>1025  CAPITAL FUNDS CT</td><td> NASHVILLE</td><td>NULL</td><td>NULL</td><td>NULL</td><td>2</td></tr><tr><td>27123</td><td>091 04 0 046.00</td><td>SINGLE FAMILY</td><td>1038  40TH AVE N, NASHVILLE</td><td>2015-02-23 00:00:00.000</td><td>40000</td><td>20150227-0016978</td><td>No</td><td>DAVIS, CRYSTAL ANN</td><td>1038  40TH AVE N, NASHVILLE, TN</td><td>0.14</td><td>URBAN SERVICES DISTRICT</td><td>20000</td><td>83000</td><td>103000</td><td>1947</td><td>3</td><td>1</td><td>0</td><td>2015-02-23</td><td>1038  40TH AVE N</td><td> NASHVILLE</td><td>1038  40TH A ...

-- %%
WITH RowNumCTE AS (
SELECT *,
             ROW_NUMBER() OVER (
                                 PARTITION BY 
	                               ParcelID, 
				       PropertyAddress, 
				       SaleDate, 
				       SalePrice,
				       LegalReference
				       ORDER BY UniqueID) AS row_num  
     FROM NvHousing
)
DELETE
FROM RowNumCTE
WHERE row_num >1
--FINDINGS: That deleted the duplicate rows
-- Out:
-- (104 rows affected)
-- Total execution time: 00:00:00.127

-- %%
--7. Delete Unwanted Columns
ALTER TABLE NvHousing  
DROP COLUMN PropertyAddress, OwnerAddress, SaleDate
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.020

-- %%
--8. Change Column Names
EXEC sp_rename 'NvHousing.SalesDateCorrected', 'SalesDate', 'COLUMN'
EXEC sp_rename 'NvHousing.PropertySplitAddress', 'PropertyAddress', 'COLUMN'
EXEC sp_rename 'NvHousing.PropertySplitCity', 'PropertyCity', 'COLUMN'
EXEC sp_rename 'NvHousing.OwnerSplitAddress', 'OwnerAddress', 'COLUMN'
EXEC sp_rename 'NvHousing.OwnerSplitCity', 'OwnerCity', 'COLUMN'
EXEC sp_rename 'NvHousing.OwnerSplitState', 'OwnerState', 'COLUMN'
-- Out:
-- Caution: Changing any part of an object name could break scripts and stored procedures.
-- Caution: Changing any part of an object name could break scripts and stored procedures.
-- Caution: Changing any part of an object name could break scripts and stored procedures.
-- Caution: Changing any part of an object name could break scripts and stored procedures.
-- Caution: Changing any part of an object name could break scripts and stored procedures.
-- Caution: Changing any part of an object name could break scripts and stored procedures.
-- Total execution time: 00:00:00.319
